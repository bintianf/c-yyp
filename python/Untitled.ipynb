# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline, BSpline

file=open('../pixel.txt')
data = file.readlines()
t = []
y1 = []
y2 = []
y3 = []
for num in data:
    t.append(float(num.split(',')[0]))
    y1.append(int(num.split(',')[1]))
    y2.append(int(num.split(',')[2]))
    y3.append(int(num.split(',')[3]))

x = range(0, 5, 1)
y = range(0, 6000, 1000)

# 3 images
# plt.figure()
# plt.xlabel('time(*10^4)')
# plt.ylabel('number of y1 molecules')
# plt.xticks(x)
# plt.yticks(y)
# plt.plot(t, y1)
# plt.axis([0, max(x), 0, 6000])
# plt.savefig("y1.png", dpi = 400)
# plt.show()


# plt.figure()
# plt.xlabel('time(*10^4)')
# plt.ylabel('number of y2 molecules')
# plt.xticks(x)
# plt.yticks(y)
# plt.plot(t, y2)
# plt.axis([0, max(x), 0, 6000])
# plt.savefig("y2.png", dpi = 400)
# plt.show()

# plt.figure()
# plt.xlabel('time(*10^4)')
# plt.ylabel('number of y3 molecules')
# plt.xticks(x)
# plt.yticks(y)
# plt.plot(t, y3)
# plt.axis([0, max(x), 0, 6000])
# plt.savefig("y3.png", dpi = 400)
# plt.show()


# 1 image

plt.figure()
plt.xlabel('time(*10^4)')
plt.ylabel('number of molecules')
plt.xticks(x)
plt.yticks(y)
plt.plot(t, y1, label = 'y1', color='red')
plt.plot(t, y2, label = 'y2', color='black')
plt.plot(t, y3, label = 'y3', color='blue')
plt.axis([0, 5, 0, 6000])
plt.legend()
plt.savefig("y.png", dpi = 400)
plt.show()
